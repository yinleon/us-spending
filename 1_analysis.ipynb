# %% [markdown]
# ## The Fall

# %% [markdown]
# On August 18, 2016, in the wake of a dwindling prison population, deputy attorney general Sally Q. Yates said the following in a Justice Department [memo](https://www.justice.gov/archives/opa/file/886311/download)

# %% [markdown]
# >Private prisons served an important role during a difficult period, but time has shown that
# they compare poorly to our own Bureau facilities. They simply do not provide the same level of
# correctional services, programs, and resources; they do not save substantially on costs; and as
# noted in a recent report by the Department' s Office oflnspector General, they do not maintain
# the same level of safety and security. The rehabilitative services that the Bureau provides, such
# as educational programs and job training, have proved difficult to replicate and outsource- and
# these services are essential to reducing recidivism and improving public safety.
#
# > For all these reasons, l am eager to enlist your help in beginning the process of
# reducing--and ultimately ending-our use of privately operated prisons.

# %% [markdown]
# The result of which, caused shares for the two largest private prison companies — GEO and CoreCivic, to fall by 35.5 and 40 percent, respectively.

# %% [markdown]
# ### GEO Group Stock Prices
# ![img](figs/pre_trump.png)
# Source: Google Finance - Yahoo Finance - MSN Money

# %% [markdown]
# ## Funding History

# %% [markdown]
# Yate's memo urged against renewing federal contracts.
#
# Analyzing records made available by USSPENDING.gov, reveals the magnitude of federal resources funnelled into private prisons.
#
# How much money does Core Civic and GEO get from the Government?
#
# Since 2000, GEO Group and CoreCivic have each recieved over `$`5.2 Billion in federal contracts.

# %%
annual_spending()

# %% [markdown]
# Source: USSpending.gov

# %% [markdown]
# That's just over `$`60 million annually, devoted to building and maintaining a network of private prisons. Below is a state-by-state analysis of where this money is going.

# %%
chloropleth(df)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~leonyin/58.embed" height="525px" width="100%"></iframe>

# %%
chloropleth(df)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~leonyin/60.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## A shift in strategy
# According to the Securities and Exchange Commission, the federal contracts (above) account for less than 16% of the two companies' revenue.
#
# Terry Dwyer an analyst with KDP Investment Advisors, [states](https://www.nytimes.com/2016/12/03/your-money/trumps-win-gives-stocks-in-private-prison-companies-a-reprieve.html) that 44% of CoreCivic’s 2015 revenue came from detention centers run on behalf of the Immigration and Customs Enforcement and the United States Marshals Service.
#
# ><h2>“These companies by their nature depend on and profit from mass incarceration”</h2> <br>- Carl Takei, staff attorney for the national prison project of the American Civil Liberties Union.
#
# Immigrants detained by private companies cost the government about `$`127 a day. [NYT](https://www.nytimes.com/2016/12/03/your-money/trumps-win-gives-stocks-in-private-prison-companies-a-reprieve.html)
#
# As noncitizens, standards are much less stringent.
#
# Higher margins, and Yate's memo may have prompted GEO and CoreCivic to shift their sights on detaining immigrants.<br>

# %% [markdown]
# ## Light in the tunnel
# Donald Trump's presidential campaign made bold promises to crack down on crime and illegal immigration.
#
# [Open secrets](https://www.opensecrets.org/pacs/lookup2.php?strID=C00382150)
# reports that GEO Group donated `$`280,845 to a super PAC that spent `$`22 million to help elect the Trump. Recently filed congressional reports also show that CoreCivic, gave `$`250,000 to support Trump’s inauguration.
#
# In celebration of Trump's victory in the US presediential election,
# ><h2>"[GEO Group] donated `$`250,000 to support Trump’s inaugural festivities"</h2>
# <br>-Pablo Parex, GEO Group's VP of corporate relations tells USA TODAY

# %% [markdown]
# ## Golden Age of Incarceration

# %% [markdown]
# Since Nov 8th, the value of stock for GEO group has risen by 100%
#
# ### GEO Group Stock Prices
# ![img](figs/post_trump.png)
# Source: Google Finance - Yahoo Finance - MSN Money

# %% [markdown]
# In response to policy changes -- open beds from Yates, and cracking down on immigration from Trump, a steady stream of new inmantes are expected to flow into vacancies within federally-funded private prisons.

# %% [markdown]
# This change is something that George Zoley, chief executive of GEO Group [embraces](https://theintercept.com/2017/02/22/geo-group-trump/),
# > <header><h2>“With the respect to detention services, in support of border security, we would continue to be the largest provider of detention services to the three largest government agencies, that is ICE, the Bureau of Prisons, and the U.S. Marshals Service,”</h2><header/> <br>-George Zoley, the chief executive GEO Group

# %% [markdown]
# ## What can Detained Immigrants Expect from this?
# Private immigration detention centers are nothing new, in fact their track records are terrible.
#
# In July, there was a [measles outbreak](https://www.nytimes.com/2016/12/03/your-money/trumps-win-gives-stocks-in-private-prison-companies-a-reprieve.html) at an immigrant detention center in Arizona run by CoreCivic for Immigration and Customs Enforcement.
#
# Inadequate medical care in GEO Group-owned immigrant prison in Reeves Texas caused dozens of unnecessary [deaths](https://www.thenation.com/article/privatized-immigrant-prison-deaths/).
#
# In a recent [law suit](https://www.washingtonpost.com/news/post-nation/wp/2017/03/05/thousands-of-ice-detainees-claim-they-were-forced-into-labor-a-violation-of-anti-slavery-laws/?utm_term=.5d622a7f49b6), GEO Group is accused of violating Colorado’s minimum wage laws by paying imigrant detainees `$`1 a day - far below the state's minimum wage laws.
#
# When it comes to privately-owned government contracts, accountability is a grey area. Jennifer D. Elzea, acting press sectrary for ICE, [said](https://www.washingtonpost.com/news/post-nation/wp/2017/03/05/thousands-of-ice-detainees-claim-they-were-forced-into-labor-a-violation-of-anti-slavery-laws/?utm_term=.5d622a7f49b6) she couldn’t comment on the litigation against GEO Group because, “ICE is not specifically a party in this suit.”
#
# There's also concern that this emerging market is artificially inflated. Mr. Takei of the A.C.L.U. [pointed out](https://www.nytimes.com/2017/03/10/your-money/immigrants-prison-stocks.html?action=click&contentCollection=your-money&module=NextInCollection&region=Footer&pgtype=article&version=column&rref=collection%2Fcolumn%2Fbusiness-strategies) that the president’s various policies have a “countervailing impact” on the companies. Apprehending more people increases the supply of detainees, while deporting them more rapidly reduces that supply. “Obviously, the A.C.L.U. will fight for these people’s rights and make sure there is due process,” he said. This could slow the pace of deportations and, ironically, help the companies.
#
#
# ## The Takeaway
# Detainment is just step one. Deportation, incaceration, and [bail](https://www.washingtonpost.com/local/this-company-is-making-millions-from-americas-broken-immigration-system/2017/03/08/43abce9e-f881-11e6-be05-1a3817ac21a5_story.html?tid=a_inl&utm_term=.b2af490cdf09)  are additional privatized services that are sprouting from policy.
#
# The versatility of private prison systems is something to behold. The same multi-billion dollar infrastructure went from detaining one undesirable group, to another. What direction in policy will shape who is detained next?

# %% [markdown]
# Was any of this information inaccurate or taken out of context?<br>
# Please, let me know.

# %% [markdown]
# # Methods
# Code used to generate plots

# %%
# %matplotlib inline
import glob

import pandas as pd
import matplotlib.pyplot as plt

# %%
# %ls data_in
# Out:
# spending_corrections_corporation_of_america.tsv.gz  spending_palantir.tsv.gz
# spending_geo_group.tsv.gz

# %%
data_in = 'data_in/spending_corrections_corporation_of_america.tsv.gz'
df_1 = pd.read_csv(data_in, sep='\t', compression='gzip')

# %%
data_in = 'data_in/spending_geo_group.tsv.gz'
df_2 = pd.read_csv(data_in, sep='\t', compression='gzip')

# %%
print("GEO Group recieved ${:,.2f} since 2000".format(
    df['dollarsobligated'].sum()))
# Out:
# GEO Group recieved $5,427,754,832.01 since 2000

# %%
def annual_spending():
    fig, ax = plt.subplots(2, figsize=[10,6])

    df_1[df_1['dollarsobligated'] > 0].groupby(
        'contract_year')['dollarsobligated'].sum().plot( 
        kind='line', marker='o', label='CoreCivic', ax=ax[0],
        title='DOJ Annual Contracts Obligations USD'
    )

    df_2[df_2['dollarsobligated'] > 0].groupby(
        'contract_year')['dollarsobligated'].sum().plot( 
        kind='line',  marker='o', label='GEO',
        color='lightblue', ax=ax[0]
    ).get_xaxis().set_visible(False)
    
    ax[0].xaxis.set_ticks(np.arange(2000, 2017, 2))

    df_1[df_1['dollarsobligated'] > 0].groupby(
        'contract_year')['dollarsobligated'].count().plot( 
        kind='line', marker='o', ax=ax[1],
        title='DOJ Number of Annual Contracts'
    )

    df_2[df_2['dollarsobligated'] > 0].groupby(
        'contract_year')['dollarsobligated'].count().plot( 
        kind='line', marker='o', color='lightblue', ax=ax[1]
    ).set_xlabel('Contract Year')

    ax[0].legend()

# %%
annual_spending()

# %%
df.groupby('contract_year')['dollarsobligated'].sum().plot(
    kind='bar', title='Annual USD Contract Obligations to CoreCivic'
).set_xlabel('Contract Year')

# %%
df[df['dollarsobligated'] > 0].groupby('contract_year')['dollarsobligated'].count().plot( 
    kind='line', marker= 'o', title='DOJ Number of Annual Contracts to CoreCivic'
).set_xlabel('Contract Year')

# %%
df[df['dollarsobligated'] > 0].groupby('contract_year')['dollarsobligated'].count().plot( 
    kind='line', marker= 'o', title='DOJ Number of Annual Contracts to GEO Group'
).set_xlabel('Contract Year')

# %% [markdown]
# ## What does this look like state-to-state?

# %%
import us
import numpy as np
import plotly

# %%
def group_df(df):
    df_t = df.copy()
    df_t['state_code'] = df_t['statecode'].str.split(':').str.get(0)
    
    df_merge = pd.merge(
        pd.merge(df_t.groupby('state_code')['unique_transaction_id'].count().reset_index(), 
                 df_t.groupby('state_code')['dollarsobligated'].sum().reset_index()),
        df_t.groupby('state_code')['dollarsobligated'].mean().reset_index(),
        on='state_code')
    
    df_merge.columns = ['state_code', 'contracts_count', 'total_dollars', 'mean_contract_amount']
    
    return df_merge

def build_annotation(df):
    S = [str(us.states.lookup(s)) for s in df['state_code'].tolist()]
    A = ["Avg. Contract Val: ${:,.2f}".format(int(a)) for a in df['mean_contract_amount'].tolist()]
    C = ["Num. of Contracts: {}".format(str(c)) for c in df['contracts_count'].tolist()]
    
    return ['<br>'.join([s,a,c]) for (s,a,c) in zip(S, A, C)]

def chloropleth(df):
    df3 = group_df(df)

    scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],
           [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

    data = [dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = df3['state_code'],
            z = df3['total_dollars'],
            locationmode = 'USA-states',
            text = build_annotation(df3),
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2)),
            colorbar = dict(
                title = "USD"))]

    layout = dict(
            title = ('2000-2017 DOJ Total Contract Value with CoreCivic<br>'
                     '(Hover for breakdown)'),
            geo = dict(
                scope='usa',
                projection=dict(type='albers usa'),
                showlakes=True,
                lakecolor='rgb(255, 255, 255)'))

    fig = dict( data=data, layout=layout )
    return plotly.plotly.iplot( fig, filename='d3-cloropleth-map-corecivic' )

# %%
plotly.tools.set_credentials_file(
    username='leonyin', api_key='')

# %% [markdown]
# ## Nice facts
# [NYT](https://www.nytimes.com/2016/12/03/your-money/trumps-win-gives-stocks-in-private-prison-companies-a-reprieve.html)
#
# The nonprofit Hamilton Project estimates that the two companies account for 85 percent of the private prison market in the United States.
#
# In July, there was a measles outbreak at an immigrant detention center in Arizona run by Corrections Corporation of America for Immigration and Customs Enforcement, a federal agency. State officials found fault with the way the institution handled it. [neg-imm]
#
# Those contracts amounted to less than 16 percent of the two companies’ revenue, according to filings with the Securities and Exchange Commission. Far more money — 44 percent of CoreCivic’s 2015 revenue, said Terry Dwyer, an analyst with KDP Investment Advisors — flowed from contracts for detention centers run on behalf of Immigration and Customs Enforcement and the United States Marshals Service.
#
# Mr. Trump’s statements have been starkly different from those of President Obama — and Hillary Clinton and Bernie Sanders, who each called for the end of private prisons.
#
# Still, because most detained immigrants are housed by private companies at a cost to the government of about `$`127 a day, any increases in incarceration of immigrants would swell the companies’ coffers.
#
#
# [CNN](http://money.cnn.com/2017/02/24/investing/private-prison-stocks-soar-trump/)
#
# The reason private prisons are back in vogue is simple: Trump has made sweeping promises to crack down on crime and illegal immigration. Wall Street calculated quickly that Trump's rhetoric is likely to translate into more people behind bars. And that means more profits for private prisons.
#
# Wall Street expects prisons to get the biggest boost from Trump's plans to deport illegal immigrants.
#
# "This will restore (the Bureau of Prison's) flexibility to manage the federal prison inmate population based on capacity needs," Trump's Justice Department said.
#
# [open secrets](https://www.opensecrets.org/pacs/lookup2.php?strID=C00382150)
#
# [NYT](https://www.nytimes.com/2017/03/10/your-money/immigrants-prison-stocks.html?action=click&contentCollection=your-money&module=NextInCollection&region=Footer&pgtype=article&version=column&rref=collection%2Fcolumn%2Fbusiness-strategies)
#
# Even more important over the short term is the administration’s declared policy of cracking down on unauthorized immigrants with waves of deportations, detentions and incarcerations, a program that will require a vast expansion of federal resources. Financial analysts say this could mean that newly detained immigrants will flow into underused buildings owned by the two companies, filling “idle” space and significantly bolstering profits.
#
# --------------->
#
# The beauty of this, for Geo, is that it could expand its business in three ways. Initially, Immigrations and Customs Enforcement will need more places to detain immigrants “because the border patrol will catch the individuals and then send them to an ICE facility,” Mr. Zoley said.
#
# But that’s only part of the picture. “Subsequently, there will be a need by the U.S. Marshal Services for those people that have committed criminal acts and need to be detained for adjudication,” he added.
#
# And further down the line, Mr. Zoley said, the federal prisons will need to incarcerate “those people who have been sentenced and need to serve their time.”
# --------->
#
# Mr. Takei of the A.C.L.U. pointed out that the president’s various policies have a “countervailing impact” on the companies. Apprehending more people increases the supply of detainees, while deporting them more rapidly reduces that supply. “Obviously, the A.C.L.U. will fight for these people’s rights and make sure there is due process,” he said. This could slow the pace of deportations and, ironically, help the companies.
#
# [WP](https://www.washingtonpost.com/news/post-nation/wp/2017/03/05/thousands-of-ice-detainees-claim-they-were-forced-into-labor-a-violation-of-anti-slavery-laws/?utm_term=.5d622a7f49b6)
#
# The original nine plaintiffs claim that detainees at the ICE facility are forced to work without pay — and that those who refuse to do so are threatened with solitary confinement. [neg-imm]
#
# GEO Group also is accused of violating Colorado’s minimum wage laws by paying detainees `$`1 day instead of the state’s minimum wage of about $9 an hour. The company “unjustly enriched” itself through the cheap labor of detainees, the lawsuit says.
#
# Jennifer D. Elzea, acting press sectrary for ICE, said she couldn’t comment on the litigation because “ICE is not specifically a party in this suit.”
